# %% [markdown]
# # Challenge 3 | Using Python to Analyze Seismic Data On Mars
#
# Imagine you are a planetary scientist, trying to get some rest after a long day of potato farming on Mars. Your alarm starts buzzing, and you check your email to find that a meteorite has just impacted, causing the equivalent shaking of a magnitude 5.7 earthquake. Your main research interest involves using data collected from instruments all over Mars to determine whether the crust of the northern hemisphere is as thick as that of the southern hemisphere.  You jump out of bed, ready to begin processing the new data, and be the first to map structural differences within Mars' interior.
#
# In this module, you'll be working toward calculating the theoretical travel times of seismic waves radiating away from a hypothetical meteorite impact on Mars. We'll focus on _surface waves_, known as Rayleigh waves, which represent seismic energy trapped primarily in the surface layer of the planet. These waves are the strongest, but the slowest traveling, among the various seismic waves that are released from the impact (such as P- and S-waves). The diagram below illustrates the different strengths, speeds, and paths of these three different types of seismic waves.
#
# ![Seismic waves](https://github.com/CIERA-Northwestern/REACHpy/blob/ideaspy_updates/Module_1/images/waves.jpg?raw=1)
#
# The speeds at which these waves travel depends on the composition of the planet they're passing through. Therefore, the arrival time differences between P, S, and Rayleigh waves, hold critical information on the state of the subsurface of the planet.
#
# While you won't yet be analyzing real data in this challenge, you'll be building a starter code that has the basic elements that would be needed to analyze data from this meteorite impact. Specifically, in this challenge you'll do the following:
#
# > - Use Python interactively<br>
# > - Perform basic mathematical operations<br>
# > - Define and use variables and equations<br>
# > - Use different data types<br>
# > - Print and format output<br>
# > - Create while loops<br>
# > - Create and execute your first standalone Python program<br>
#
#
# Since we're trying to calculate the theoretical travel times of the surface waves radiating away from the impact, we'll need to write a code that can compute the travel time for a wave that has traveled for any arbitrary distance, based on the properties of these surface waves. Then, we'll want our code to be able to loop over a series of provided distances, finally printing out a list of the theoretical travel times. And now, you've got the skills to do just that!

# %% [markdown]
# ## The Physics
#
# To compute the theoretical travel time, you just need this simple equation:
#
# $t=\frac{d \, \times \, kpd}{v}$
#
# Let's define each of these variables:
#
# > - $t$ is the theoretical travel time of the wave in seconds<br>
# ><br>
# > - $d$ is the angular distance in degrees from the origin of the impact to the detector<br>
# ><br>
# > - $kpd$ is a conversion factor from (km per degree): $kpd=\frac{\pi R}{180}$<br>
# ><br>
# > - $R$ (above) is the average radius of the Mars:  $R = 3390$ km<br>
# ><br>
# > - $v$ is the average velocity of the surface waves through the Mars in km/sec<br>
# ><br>
#
#
# If you think about the units of these quantities, the equation should make sense.
#
# ## Build Your Code

# %% [markdown]
# Set the variables needed (the constants in this problem) in the cell below:
# > - Assume the average radius of Mars, R,  3390.0 (km)<br>
# > - Assume average surface-wave velocity v = 4 (km/s)<br>
# > - Set the conversion factor kpd<br>
# > - Convert angular distances between degrees to kilometers<br>

# %%
import numpy as np

r_Mars = 3.39*10**3
v_s_wave = 4
kpd = np.pi * r_Mars / 180

cir_Mars = 2 * np.pi * r_Mars
deg = 10
dist_deg = cir_Mars * 360 / deg

# %% [markdown]
# Write an equation to calculate the travel time of a surface wave travel time, t, in seconds for a distance of 10 degrees in the cell below:

# %%
deg = 10
t = (deg * kpd) / v_s_wave
print(t)
# Out:
# 147.91665410651942

# %% [markdown]
# Print both the distance d, and the travel time t, on the same line, for all distances 0 through 100 degrees.

# %%
for deg in range(101):
    dist_deg = deg * kpd
    t = dist_deg / v_s_wave
    print(f'deg = {deg:>3d}, dist_deg = {dist_deg:7.2f} km, time = {t:7.2f} seconds')
# Out:
# deg =   0, dist_deg =    0.00 km, time =    0.00 seconds
# deg =   1, dist_deg =   59.17 km, time =   14.79 seconds
# deg =   2, dist_deg =  118.33 km, time =   29.58 seconds
# deg =   3, dist_deg =  177.50 km, time =   44.37 seconds
# deg =   4, dist_deg =  236.67 km, time =   59.17 seconds
# deg =   5, dist_deg =  295.83 km, time =   73.96 seconds
# deg =   6, dist_deg =  355.00 km, time =   88.75 seconds
# deg =   7, dist_deg =  414.17 km, time =  103.54 seconds
# deg =   8, dist_deg =  473.33 km, time =  118.33 seconds
# deg =   9, dist_deg =  532.50 km, time =  133.12 seconds
# deg =  10, dist_deg =  591.67 km, time =  147.92 seconds
# deg =  11, dist_deg =  650.83 km, time =  162.71 seconds
# deg =  12, dist_deg =  710.00 km, time =  177.50 seconds
# deg =  13, dist_deg =  769.17 km, time =  192.29 seconds
# deg =  14, dist_deg =  828.33 km, time =  207.08 seconds
# deg =  15, dist_deg =  887.50 km, time =  221.87 seconds
# deg =  16, dist_deg =  946.67 km, time =  236.67 seconds
# deg =  17, dist_deg = 1005.83 km, time =  251.46 seconds
# deg =  18, dist_deg = 1065.00 km, time =  266.25 seconds
# deg =  19, dist_deg = 1124.17 km, time =  281.04 seconds
# deg =  20, dist_deg = 1183.33 km, time =  295.83 seconds
# deg =  21, dist_deg = 1242.50 km, time =  310.62 seconds
# deg =  22, dist_deg = 1301.67 km, time =  325.42 seconds
# deg =  23, dist_deg = 1360.83 km, time =  340.21 seconds
# deg =  24, dist_deg = 1420.00 km, time =  355.00 seconds
# deg =  25, dist_deg = 1479.17 km, time =  369.79 seconds
# deg =  26, dist_deg = 1538.33 km, time =  384.58 seconds
# deg =  27, dist_deg = 1597.50 km, time =  399.37 seconds
# deg =  28, dist_deg = 1656.67 km, time =  414.17 seconds
# deg =  29, dist_deg = 1715.83 km, time =  428.96 seconds
# deg =  30, dist_deg = 1775.00 km, time =  443.75 seconds
# deg =  31, dist_deg = 1834.17 km, time =  458.54 seconds
# deg =  32, dist_deg = 1893.33 km, time =  473.33 seconds
# deg =  33, dist_deg = 1952.50 km, time =  488.12 seconds
# deg =  34, dist_deg = 2011.67 km, time =  502.92 seconds
# deg =  35, dist_deg = 2070.83 km, time =  517.71 seconds
# deg =  36, dist_deg = 2130.00 km, time =  532.50 seconds
# deg =  37, dist_deg = 2189.17 km, time =  547.29 seconds
# deg =  38, dist_deg = 2248.33 km, time =  562.08 seconds
# deg =  39, dist_deg = 2307.50 km, time =  576.87 seconds
# deg =  40, dist_deg = 2366.67 km, time =  591.67 seconds
# deg =  41, dist_deg = 2425.83 km, time =  606.46 seconds
# deg =  42, dist_deg = 2485.00 km, time =  621.25 seconds
# deg =  43, dist_deg = 2544.17 km, time =  636.04 seconds
# deg =  44, dist_deg = 2603.33 km, time =  650.83 seconds
# deg =  45, dist_deg = 2662.50 km, time =  665.62 seconds
# deg =  46, dist_deg = 2721.67 km, time =  680.42 seconds
# deg =  47, dist_deg = 2780.83 km, time =  695.21 seconds
# deg =  48, dist_deg = 2840.00 km, time =  710.00 seconds
# deg =  49, dist_deg = 2899.17 km, time =  724.79 seconds
# deg =  50, dist_deg = 2958.33 km, time =  739.58 seconds
# deg =  51, dist_deg = 3017.50 km, time =  754.37 seconds
# deg =  52, dist_deg = 3076.67 km, time =  769.17 seconds
# deg =  53, dist_deg = 3135.83 km, time =  783.96 seconds
# deg =  54, dist_deg = 3195.00 km, time =  798.75 seconds
# deg =  55, dist_deg = 3254.17 km, time =  813.54 seconds
# deg =  56, dist_deg = 3313.33 km, time =  828.33 seconds
# deg =  57, dist_deg = 3372.50 km, time =  843.12 seconds
# deg =  58, dist_deg = 3431.67 km, time =  857.92 seconds
# deg =  59, dist_deg = 3490.83 km, time =  872.71 seconds
# deg =  60, dist_deg = 3550.00 km, time =  887.50 seconds
# deg =  61, dist_deg = 3609.17 km, time =  902.29 seconds
# deg =  62, dist_deg = 3668.33 km, time =  917.08 seconds
# deg =  63, dist_deg = 3727.50 km, time =  931.87 seconds
# deg =  64, dist_deg = 3786.67 km, time =  946.67 seconds
# deg =  65, dist_deg = 3845.83 km, time =  961.46 seconds
# deg =  66, dist_deg = 3905.00 km, time =  976.25 seconds
# deg =  67, dist_deg = 3964.17 km, time =  991.04 seconds
# deg =  68, dist_deg = 4023.33 km, time = 1005.83 seconds
# deg =  69, dist_deg = 4082.50 km, time = 1020.62 seconds
# deg =  70, dist_deg = 4141.67 km, time = 1035.42 seconds
# deg =  71, dist_deg = 4200.83 km, time = 1050.21 seconds
# deg =  72, dist_deg = 4260.00 km, time = 1065.00 seconds
# deg =  73, dist_deg = 4319.17 km, time = 1079.79 seconds
# deg =  74, dist_deg = 4378.33 km, time = 1094.58 seconds
# deg =  75, dist_deg = 4437.50 km, time = 1109.37 seconds
# deg =  76, dist_deg = 4496.67 km, time = 1124.17 seconds
# deg =  77, dist_deg = 4555.83 km, time = 1138.96 seconds
# deg =  78, dist_deg = 4615.00 km, time = 1153.75 seconds
# deg =  79, dist_deg = 4674.17 km, time = 1168.54 seconds
# deg =  80, dist_deg = 4733.33 km, time = 1183.33 seconds
# deg =  81, dist_deg = 4792.50 km, time = 1198.12 seconds
# deg =  82, dist_deg = 4851.67 km, time = 1212.92 seconds
# deg =  83, dist_deg = 4910.83 km, time = 1227.71 seconds
# deg =  84, dist_deg = 4970.00 km, time = 1242.50 seconds
# deg =  85, dist_deg = 5029.17 km, time = 1257.29 seconds
# deg =  86, dist_deg = 5088.33 km, time = 1272.08 seconds
# deg =  87, dist_deg = 5147.50 km, time = 1286.87 seconds
# deg =  88, dist_deg = 5206.67 km, time = 1301.67 seconds
# deg =  89, dist_deg = 5265.83 km, time = 1316.46 seconds
# deg =  90, dist_deg = 5325.00 km, time = 1331.25 seconds
# deg =  91, dist_deg = 5384.17 km, time = 1346.04 seconds
# deg =  92, dist_deg = 5443.33 km, time = 1360.83 seconds
# deg =  93, dist_deg = 5502.50 km, time = 1375.62 seconds
# deg =  94, dist_deg = 5561.67 km, time = 1390.42 seconds
# deg =  95, dist_deg = 5620.83 km, time = 1405.21 seconds
# deg =  96, dist_deg = 5680.00 km, time = 1420.00 seconds
# deg =  97, dist_deg = 5739.17 km, time = 1434.79 seconds
# deg =  98, dist_deg = 5798.33 km, time = 1449.58 seconds
# deg =  99, dist_deg = 5857.50 km, time = 1464.37 seconds
# deg = 100, dist_deg = 5916.67 km, time = 1479.17 seconds

# %% [markdown]
# ## Check Your Code
#
# To make sure your code is producing the right values:
# > - Set your variable used to represent the degrees between the impact and seismic station to 65 degrees<br>
# > - Your code should produce a surface-wave travel time of about 961 seconds <br>

# %%
deg = 65
t = (deg * kpd) / v_s_wave
print(f'deg = {deg}, dist_deg = {dist_deg:7.2f} km, time = {t:6.2f} seconds')
# Out:
# deg = 65, dist_deg = 5916.67 km, time = 961.46 seconds
